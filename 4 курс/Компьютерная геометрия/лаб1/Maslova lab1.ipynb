# %% [markdown]
# ## Лабораторная работа №1
# - ФИО: **Маслова Анастасия**
# - Номер студ. билета: **1032216455**
# - Группа: **НКНбд-01-21**

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import math

# %% [markdown]
# # Задание 1

# %% [markdown]
# ## 1.1
# Постройте декартову плоскость координат с осями 𝑂𝑥 и 𝑂𝑦, с разметкой по осям. На осях 𝑂𝑥 и 𝑂𝑦 отметьте целочисленные координаты в диапазоне [−𝑛, 𝑛], где 𝑛 — конкретное целое число. Координатная сетка на плоскости должна рисоваться автоматически. Границы (лимиты) осей задайте явно. В качестве примера ориентируйтесь на рисунок 1.

# %%
n = 10
plt.figure(figsize=(8, 8), dpi=200)
plt.xlim(-n, n)
plt.ylim(-n, n)
plt.axhline(0, color='black',linewidth=1) 
plt.axvline(0, color='black',linewidth=1)
plt.grid(True)
plt.grid(color='gray', linewidth=0.5)
plt.style.use("default")
plt.show()

# %% [markdown]
# ## 1.2
# Теперь отключите автоматическую координатную сетку и нарисуйте ее вручную так, чтобы вся плоскость покрылась квадратными клетками 1 × 1. Используйте функции, которые рисуют отрезки.

# %%
n = 10
plt.figure(figsize=(8, 8), dpi=200)
plt.xlim(-n, n)
plt.ylim(-n, n)
plt.axline((0,10), (0,-10), color='black',linewidth=0.8) 
plt.axline((-10, 0), (10, 0), color='black',linewidth=0.8)
plt.grid(False)
plt.style.use("default")
for i in range(-n+1, 0):
    plt.axline((-n, i), (n, i), color='black',linewidth=0.5, linestyle='--') # horiz
    plt.axline((i, n), (i, -n), color='black',linewidth=0.5, linestyle='--') # vertic
for i in range(1, n+1):
    plt.axline((-n, i), (n, i), color='black',linewidth=0.5, linestyle='--') # horiz
    plt.axline((i, n), (i, -n), color='black',linewidth=0.5, linestyle='--') # vertic
plt.show()

# %% [markdown]
# ## 1.3
# Настройте вид линий, изменив цвет, стиль (пунктир, штрихпунктир, штрих и т.д.), толщину и т.д.

# %%
n = 10
plt.figure(figsize=(8, 8), dpi=200)
plt.xlim(-n, n)
plt.ylim(-n, n)
plt.axline((0,10), (0,-10), color='black',linewidth=0.8) 
plt.axline((-10, 0), (10, 0), color='black',linewidth=0.8)
plt.grid(False)
plt.style.use("default")
for i in range(-n+1, 0):
    plt.axline((-n, i), (n, i), color='red',linewidth=0.9, linestyle=':') # horiz
    plt.axline((i, n), (i, -n), color='yellow',linewidth=0.6, linestyle='-.') # vertic
for i in range(1, n+1):
    plt.axline((-n, i), (n, i), color='blue',linewidth=0.3, linestyle='--') # horiz
    plt.axline((i, n), (i, -n), color='green',linewidth=1.3, linestyle='-') # vertic
plt.show()

# %% [markdown]
# ## 1.4
# Вновь нарисуйте координатную сетку, но теперь используйте функции для рисования бесконечных прямых.

# %%
n = 10
plt.figure(figsize=(8, 8), dpi=200)
plt.xlim(-n, n)
plt.ylim(-n, n)
plt.axhline(0, color='black',linewidth=0.5) 
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(False)
plt.style.use("default")
for i in range(-n+1, n+1):
    plt.vlines(i, -n, n, colors='black', linestyles=':', linewidth=0.5)
    plt.hlines(i, -n, n, colors='black', linestyles=':', linewidth=0.5)
plt.show()

# %% [markdown]
# # 1.5
# Нарисуйте теперь диагональные прямые, как это показано на рисунке 2

# %%
n = 10
plt.figure(figsize=(8, 8), dpi=200)
plt.xlim(-n, n)
plt.ylim(-n, n)
plt.axhline(0, color='black',linewidth=0.5) 
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(False)
plt.style.use("default")

for i in range(-n+1, n+1):
    plt.vlines(i, -n, n, colors='black', linestyles=':', linewidth=0.5)
    plt.hlines(i, -n, n, colors='black', linestyles=':', linewidth=0.5)

for i in range(-4*n, 4*n):
    plt.axline((i, 0), slope=np.tan(np.pi/8), color='black', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# slope в функции axlines - наклон, с которым рисуются линии, рассчитывается как отношение изменения высоты по вертикали к изменению высоты по горизонтали.
# Например, имеются точка А(3,2) и В(5,4). Δx=2, Δy=2. slope = 1.

# %% [markdown]
# # Задание 2

# %% [markdown]
# ## 2.1
# Нарисуйте два произвольных вектора. Найдите ориентированный угол между ними, для чего используйте функцию arctan2. Проверьте корректность вычислений на примерах острого, тупого и прямого углов.

# %%
x1 = 1
y1 = 1
x2 = 2
y2 = -3
n = 10

vector1 = np.array([x1, y1])
vector2 = np.array([x2, y2])

# %%
plt.figure(figsize=(8, 8), dpi=200)  

plt.quiver(0, 0, vector1[0], vector1[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Вектор 1')

plt.quiver(0, 0, vector2[0], vector2[1], angles='xy', scale_units='xy', scale=1, color='red', label='Вектор 2')

angle_radians = np.arctan2(np.linalg.det([vector1, vector2]), np.dot(vector1, vector2))

angle_degrees = np.degrees(angle_radians) 

plt.text(0.5, 3.5, f'Угол между векторами: {angle_degrees:.2f} градусов', fontsize=11)

plt.xlim(-n, n)  
plt.ylim(-n, n)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.legend()  
plt.title('Векторы и угол между ними')  
plt.xlabel('X') 
plt.ylabel('Y')  
plt.show()

# %% [markdown]
# ## 2.2
# Примените к векторам такое линейное преобразование, чтобы ориентированный угол поменял свой знак. Какому условию должна удовлетворять матрица такого преобразования?

# %%
transformation_matrix = np.array([[1, 0], [0, -1]])

trans_vector1 = transformation_matrix @ vector1
trans_vector2 = transformation_matrix @ vector2

# %%
plt.figure(figsize=(8, 8), dpi=200)  

plt.quiver(0, 0, trans_vector1[0], trans_vector1[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Вектор 1')

plt.quiver(0, 0, trans_vector2[0], trans_vector2[1], angles='xy', scale_units='xy', scale=1, color='red', label='Вектор 2')

trans_angle_radians = np.arctan2(np.linalg.det([trans_vector1, trans_vector2]), np.dot(trans_vector1, trans_vector2))

trans_angle_degrees = np.degrees(trans_angle_radians) 

plt.text(0.5, 3.5, f'Угол между векторами: {trans_angle_degrees:.2f} градусов', fontsize=11)

plt.xlim(-n, n)  
plt.ylim(-n, n)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.legend()  
plt.title('Векторы и угол между ними')  
plt.xlabel('X') 
plt.ylabel('Y')  
plt.show()

# %% [markdown]
# ## 2.3
# Нарисуйте то же самое переключившись в полярную систему координат, получившееся изображения должно
# быть похоже на рисунки 3 и 4.

# %%
np.degrees(math.acos((x1*y1 + x2*y2) / (np.sqrt(x1**2 + x2**2) + np.sqrt(y1**2 + y2**2))))
# Out:
# 157.85147747462776

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, dpi=200)

theta1 = np.arctan2(vector1[1], vector1[0])
theta2 = np.arctan2(vector2[1], vector2[0])

ax.plot([0, theta1], [0, 3], label='Вектор 1', color='blue')
ax.plot([0, theta2], [0, 3], label='Вектор 2', color='red')

ax.set_ylim(0,5)

ax.set_xticks(np.linspace(0,2*np.pi,12,endpoint=False))
ax.set_yticks(np.arange(1,5,1))

ax.legend()

ax.set_title('Векторы и угол между ними в полярной системе координат')
plt.show()

# %% [markdown]
# # Задание 3
#
# Написать программу, которая рисует произвольный многоугольник по заданным координатам всех его вершин. Должна быть возможность задавать любое количество вершин в виде массива точек.

# %%
vertices = np.array([(0,0), (1, -3), (4, -2), (4, 1), (2, 2)])

def plot_the_polygon(vertices):
    fig, ax = plt.subplots(figsize=(5, 5), dpi=200)
    polygon = Polygon(vertices, closed=True, fill=False, edgecolor='b', linewidth=2)
    ax.add_patch(polygon)

    x_coords = vertices[:, 0]
    y_coords = vertices[:, 1]
    ax.plot(x_coords, y_coords, 'ro', markersize=7) # здесь менять маркеры для точек

    plt.xlim(-5, 5)  
    plt.ylim(-5, 5)  
    plt.axhline(0, color='black', linewidth=0.5)  
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)  
    plt.title('Произвольный многоугольник')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()

plot_the_polygon(vertices)

# %% [markdown]
# ## 3.1
#
# Вычислите ориентированную площадь многоугольника. Проверьте корректность вычислений на примере правильного многоугольника, площадь которого можно вычислить теоретически. Простейший пример изображен на рисунке 5.

# %%
def oriented_area(vertices):
    n = len(vertices)
    area = 0
    for i in range(n):
        j = (i + 1) % n
        area += vertices[i][0] * vertices[j][1]
        area -= vertices[j][0] * vertices[i][1]
    return 0.5 * area

area = oriented_area(vertices)
print("Ориентированная площадь многоугольника =", area)
# Out:
# Ориентированная площадь многоугольника = 14.0

# %% [markdown]
# ## 3.2
# Приведите пример преобразования, которое меняет знак ориентированной площади многоугольника. Пример изображен на рисунке 6. Примените это преобразование к вашему многоугольнику.

# %%
vertices_modified = np.dot(vertices, transformation_matrix)

plot_the_polygon(vertices_modified)

# %%
oriented_area(vertices_modified)
# Out:
# -14.0

# %% [markdown]
# ## 3.3
#
# Выделите вершины многоугольника маркерными точками. Как настроить размер маркеров? Цвет? Форму?
#
# ------------------
#
# Вершины уже выделены в коде выше. Настроить размер, цвет и форму маркеров можно в той строчке кода, которую я выделила комментарием.

# %% [markdown]
# ## 3.4
#
# Покажите стрелками направление обхода вершин, как это показано на рисунках 5 и 6.

# %%
def plot_the_polygon_oriented(vertices):
    x_coords = vertices[:, 0]
    y_coords = vertices[:, 1]

    fig, ax = plt.subplots(figsize=(5, 5), dpi=200)

    for i in range(len(x_coords)):
        if (i==len(x_coords)-1):
            ax.quiver(x_coords[i], y_coords[i], x_coords[0]-x_coords[i], y_coords[0]-y_coords[i], angles='xy', scale_units='xy', scale=1, color='blue')
        else: 
            ax.quiver(x_coords[i], y_coords[i], x_coords[i+1]-x_coords[i], y_coords[i+1]-y_coords[i], angles='xy', scale_units='xy', scale=1, color='blue')

    plt.xlim(-5, 5)  
    plt.ylim(-5, 5)  
    plt.axhline(0, color='black', linewidth=0.5)  
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)  
    plt.title('Произвольный многоугольник')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()

plot_the_polygon_oriented(vertices)

# %% [markdown]
# # Задание 4
#
# Нарисуйте график циклоиды для двух полных оборотов окружности. Отобразите единичные касательные и нормальные векторы в некоторых точках циклоиды.

# %%
PI = 3.1415926535

# %%
r = 2
t = np.linspace(0, 4 * np.pi, 100)

matrix = np.array([0, -1, 1, 0]).reshape(2,2)

x = r * (t - np.sin(t))
y = r * (1 - np.cos(t))

dx = r - r * np.cos(t)
dy = r * np.sin(t)

nx = []*100
ny = []*100

for i in range(0, 100):
    nx.append(np.array(np.dot(matrix, np.array([dx[i], dy[i]])))[0])
    ny.append(np.array(np.dot(matrix, np.array([dx[i], dy[i]])))[1])

fig, ax = plt.subplots(figsize=(5, 3), dpi=200)

ax.plot(x, y, linewidth=1, color='black', label=r'Циклоида')
ax.quiver(x[::6], y[::6], dx[::6], dy[::6], units='xy', angles='xy', color='blue', width=0.1, scale=2, label='Горизонтальные касательные векторы')
ax.quiver(x[::6], y[::6], nx[::6], ny[::6], units='xy', angles='xy', color='red', width=0.1, scale=2, label='Вертикальные касательные векторы')


plt.xlim(0, 15)  
plt.ylim(0, 9)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.title('Циклоида')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # Задание 5
#
# Написать программу, которая рисует правильный многоугольник с центром в заданной точке, а также вписанную и описанную окружности этого многоугольника см. рис. 8. Количество сторон правильного 𝑛-угольника и длинуего стороны нужно задать в виде параметра. Вместо длины стороны можно использовать радиус 𝑟 вписанной или радиус 𝑅 описанной окружностей.
#
# - Все вершины многоугольника должны быть выделены маркерами и подписаны как 𝑃1, 𝑃2 и т.д.
# - Нумерация точек должна осуществляться автоматически, в зависимости от 𝑛.
# - Радиусы окружностей должны быть нарисованы в виде отрезков.
# - Стороны многоугольника должны быть нарисованы более толстыми линиями, чем остальные элементы изображения.
# - Описанная и вписанная окружности должны быть нарисованы разными цветами.
# - Масштаб изображения не должен быть искажен (окружности не должны выглядеть как эллипсы).
# - Картинка должна корректно перерисовываться при изменении 𝑛

# %%
n = 5
R = 2.0  
r = R * np.cos(np.pi / n)  

theta = np.linspace(0, 2 * np.pi, n, endpoint=False)
x_coords = R * np.cos(theta)
y_coords = R * np.sin(theta)

fig = plt.figure(figsize=(8, 8), dpi=200)

circle_outside = plt.Circle((0, 0), R, color='blue', fill=False, linestyle='dashed', linewidth=2)
plt.gca().add_patch(circle_outside)

circle_inside = plt.Circle((0, 0), r, color='red', fill=False, linestyle='dashed', linewidth=2)
plt.gca().add_patch(circle_inside)

plt.plot(x_coords, y_coords, color='black', marker='o', markersize=6)

for i, (x, y) in enumerate(zip(x_coords, y_coords), start=1):
    plt.text(x, y, f'$P_{{{i}}}$', fontsize=12, ha='right', va='bottom')

for i in range(n):
    plt.plot([x_coords[i], x_coords[(i + 1) % n]], [y_coords[i], y_coords[(i + 1) % n]], color='black', linewidth=3)

plt.xlim(-R - 1, R + 1)  
plt.ylim(-R - 1, R + 1)  
plt.gca().set_aspect('equal', adjustable='box')  
plt.grid(True)

plt.title(f'Правильный {n}-угольник и его окружности') 
plt.xlabel('X')  
plt.ylabel('Y')  
plt.show()

# %% [markdown]
# ## Задание 6
#
# Нарисовать конические сечения: эллипс, гиперболу и параболу в каноническом виде.

# %%
a = 5
b = 3
t = np.linspace(0, 4 * np.pi, 100)

x = a * np.cos(t)
y = b * np.sin(t)

fig, ax = plt.subplots(figsize=(5, 5), dpi=200)

ax.plot(x, y, linewidth=1, color='green')

plt.xlim(-15, 15)  
plt.ylim(-15, 15)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.title('Эллипс')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
a = 3
b = 2
t = np.linspace(-4*np.pi, 4 * np.pi, 100)

x = a * np.cosh(t)
y = b * np.sinh(t)

xx = -a * np.cosh(t)
yy = -b * np.sinh(t)

fig, ax = plt.subplots(figsize=(5, 5), dpi=200)

ax.plot(x, y, linewidth=1, color='green')
ax.plot(xx, yy, linewidth=1, color='green')

plt.xlim(-15, 15)  
plt.ylim(-15, 15)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.title('Гипербола')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
a = 3
b = 2
t = np.linspace(-4*np.pi, 4 * np.pi, 100)

x = a * t**2
y = a * 2 * t


fig, ax = plt.subplots(figsize=(5, 5), dpi=200)

ax.plot(x, y, linewidth=1, color='green')

plt.xlim(-15, 15)  
plt.ylim(-15, 15)  
plt.axhline(0, color='black',linewidth=0.5)  
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)  
plt.title('Парабола в каноническом виде')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
